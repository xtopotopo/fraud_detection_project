# %%
from kafka import KafkaConsumer
import fastavro
import io

# Kafka Configuration
KAFKA_BROKER = "host.docker.internal:9092"  # Change if needed
TOPIC = "fraud_prediction"
GROUP_ID = "fraud_consumer_group"

# Avro Schema for Deserialization
avro_schema = {
    "type": "record",
    "name": "FraudPrediction",
    "namespace": "com.fraud.detection",
    "fields": [
        {"name": "prediction", "type": "int"}
    ]
}

def deserialize_avro(avro_bytes):
    """ Deserialize Avro binary message to Python dict """
    with io.BytesIO(avro_bytes) as buff:
        record = next(fastavro.reader(buff, avro_schema))
        return record

# Initialize Kafka Consumer
consumer = KafkaConsumer(
    TOPIC,
    bootstrap_servers=KAFKA_BROKER,
    group_id=GROUP_ID,
    key_deserializer=lambda k: k.decode("utf-8") if k else None,  # Decode key as string
    value_deserializer=lambda v: deserialize_avro(v) if v else None,
    auto_offset_reset="earliest",  # Read from beginning if no offset
    enable_auto_commit=True
)

print(f"Listening for messages on topic: {TOPIC}...")

# Consume messages
for message in consumer:
    key = message.key
    prediction = message.value.get("prediction") if message.value else None
    print(f"Transaction ID: {key} | Fraud Prediction: {prediction}")
# Out:
# Listening for messages on topic: fraud_prediction...
# Transaction ID: 26c10a6e-deac-4c38-8fea-987915f2226b | Fraud Prediction: 1
# Transaction ID: 605bf8f1-814e-4260-8133-7dfc079f6dd5 | Fraud Prediction: 0
# Transaction ID: 07652d98-a1f7-4cfa-86b5-0a73adf92152 | Fraud Prediction: 0
# Transaction ID: b2f0b6d0-c0ef-411c-a42e-01c72e4aa8c1 | Fraud Prediction: 0
# Transaction ID: 2211ac33-73ee-45e8-9e57-0396c5acc0ed | Fraud Prediction: 0
# Transaction ID: 57862c35-88fc-4b97-8e07-709b7e64d634 | Fraud Prediction: 1
# Transaction ID: 6fa6b241-cb42-4be9-b8b3-b618e506efe8 | Fraud Prediction: 0
# Transaction ID: 892b3b21-1b9b-482c-a50a-ad78b8c450d8 | Fraud Prediction: 1
# Transaction ID: 031df3c8-df4c-4aca-b2c4-f278405b53b6 | Fraud Prediction: 1
# Transaction ID: cf46191e-0f75-45b0-8090-c1d03e8cbd29 | Fraud Prediction: 1
# Transaction ID: 7da9982e-518e-42e9-8672-3bc10f8ecefa | Fraud Prediction: 0
# Transaction ID: 91a61f40-d026-4bbb-851f-004d8e783a1b | Fraud Prediction: 0
# Transaction ID: 9e4cbd6f-3d85-455e-b476-aac1e48f1b76 | Fraud Prediction: 0
# Transaction ID: d0e161ae-cad7-4187-931a-0bf685fcc470 | Fraud Prediction: 1
# Transaction ID: a3070e3b-4686-48ff-9c86-502812113cf7 | Fraud Prediction: 1
# Transaction ID: a06a063d-5837-487e-8dbb-1b0df1a7233d | Fraud Prediction: 1
# Transaction ID: d8904356-899f-4748-a971-5acb48d0b0ae | Fraud Prediction: 1
# Transaction ID: 670d9209-ca8e-4cad-9c5f-37c8974b7672 | Fraud Prediction: 1
# Transaction ID: 2d631932-3c8b-433f-b241-51c29f6e8958 | Fraud Prediction: 1
# Transaction ID: 3b5591d9-e13c-4099-8df0-1597193b929d | Fraud Prediction: 0
# Transaction ID: db9c00ab-f940-4db8-922c-8bbe8bf5ed34 | Fraud Prediction: 1
# Transaction ID: 474a068b-8a80-40fc-b37b-e5fbd21fac4a | Fraud Prediction: 0
# Transaction ID: e156e49b-b4aa-48ae-9eaa-5d3eb5d00dbd | Fraud Prediction: 0
# Transaction ID: 0ca99518-2d4b-4abf-a23c-f0da5658b2f9 | Fraud Prediction: 1
# Transaction ID: 48c51c4b-d1f7-486a-b25d-4341fe5fe096 | Fraud Prediction: 0
# Transaction ID: eec8d516-4d19-4157-ab2b-aeb45acda64e | Fraud Prediction: 1
# Transaction ID: 593e54e6-27ff-41c2-9b33-435b1d6e898a | Fraud Prediction: 1
# Transaction ID: 34166867-64c4-4502-9dd9-7e540dc65259 | Fraud Prediction: 1
# Transaction ID: ebc1778d-e9b9-45fb-a84d-358d67c07ce5 | Fraud Prediction: 1
# Transaction ID: 0b824efd-b521-4ef3-8068-247fda0b2d20 | Fraud Prediction: 1
# Transaction ID: 8480712e-e24b-47b8-9ef3-6af28542cd6c | Fraud Prediction: 1
# Transaction ID: e6b6e6ec-54d8-4dde-b3c4-6074ce1a63b1 | Fraud Prediction: 1
# Transaction ID: fe793594-eac4-4fe3-a18b-1a6c68e2e534 | Fraud Prediction: 0
# Transaction ID: 71daa9f9-78c9-474b-ab85-25cef4cf20aa | Fraud Prediction: 1
# Transaction ID: 9b3eb16c-551d-484c-8bf2-34f1dfa451e3 | Fraud Prediction: 0
# Transaction ID: c82af4d9-70dc-40af-b69e-cac7714a9fcb | Fraud Prediction: 1
# Transaction ID: 0a73e548-efb9-4b9f-abaa-323110fe16fc | Fraud Prediction: 1
# Transaction ID: b8f09f88-fc60-46fb-b3ba-17b4e9ede6e5 | Fraud Prediction: 1
# Transaction ID: 35271a21-dc8d-4a69-add1-3e53588b83cb | Fraud Prediction: 0
# Transaction ID: 49601a24-ef18-4eb7-b5cc-28c9e9bab171 | Fraud Prediction: 1
# Transaction ID: d384a4b4-db0f-4b2e-bcdb-176555d8376d | Fraud Prediction: 0
# Transaction ID: 6a478676-543a-4c07-bbb7-e8126bc02580 | Fraud Prediction: 1
# Transaction ID: f07f9b99-6fc3-4e0c-bf63-0b574363e9d4 | Fraud Prediction: 0
# Transaction ID: 15556b49-c0c2-458e-94d7-cd9665378b0c | Fraud Prediction: 1
# Transaction ID: edbdac9f-e2c7-459e-ad0d-8a435ba6aa4d | Fraud Prediction: 0
# Transaction ID: 397654a3-9a35-4012-abaa-faacf6005d40 | Fraud Prediction: 1
# Transaction ID: 58f56d2a-a98f-425e-9971-4303a2e42714 | Fraud Prediction: 0
# Transaction ID: 410ea529-4f99-4c1e-8501-dc7abef7e33d | Fraud Prediction: 0
# Transaction ID: dd23b558-ba76-4ff6-969f-39296b78a4aa | Fraud Prediction: 0
# Transaction ID: 0c0b1e56-40ef-4c9a-a58b-4dc8a806c6a6 | Fraud Prediction: 1
# Transaction ID: d72087c2-6a69-45f4-8173-b01471d07c4b | Fraud Prediction: 0
# Transaction ID: 38d7adbb-e195-4783-8795-f0eda3c3bbe5 | Fraud Prediction: 1
# Transaction ID: ed5104bc-177f-4e18-a3a6-537a81be1ed5 | Fraud Prediction: 1
# Transaction ID: 539b591d-42d5-438a-836c-0d4466498df1 | Fraud Prediction: 1
# Transaction ID: 62475fb9-811b-480a-afa6-28ea6e6a674e | Fraud Prediction: 0
# Transaction ID: 68e5800b-4702-465c-b3d6-eed8222b5da9 | Fraud Prediction: 1
# Transaction ID: 7ab84064-ab4d-43ce-acae-479a2ae19275 | Fraud Prediction: 0
# Transaction ID: c68043aa-d6a8-4c0b-a43c-9c17ab1828b3 | Fraud Prediction: 1
# Transaction ID: 42147eb7-1ca6-4e8a-8a9b-82528561a912 | Fraud Prediction: 0
# Transaction ID: 0752b48f-e028-4316-bdba-47940a6dc668 | Fraud Prediction: 0
