# %%
import json
import random
import uuid
import time
from confluent_kafka import Producer
import fastavro
from fastavro.schema import load_schema
import io

# Avro schema (hardcoded)
avro_schema = {
    "type": "record",
    "name": "CreditTransaction",
    "namespace": "com.fraud.detection",
    "fields": [
        {
            "name": "client_id",
            "type": "string"
        },
        {
            "name": "transaction_id",
            "type": "string"
        },
        {
            "name": "type",
            "type": ["string", "null"],
            "default": None
        },
        {
            "name": "amount",
            "type": ["double", "null"],
            "default": None
        },
        {
            "name": "oldbalanceOrg",
            "type": ["double", "null"],
            "default": None
        },
        {
            "name": "newbalanceOrig",
            "type": ["double", "null"],
            "default": None
        }
    ]
}

# Kafka Producer Configuration
KAFKA_BROKER = "host.docker.internal:9092"  # Replace with your Kafka broker
TOPIC = "raw_credit_data"  # Kafka topic to send data to

# Initialize Kafka producer
conf = {
    'bootstrap.servers': KAFKA_BROKER,
    'acks': 'all',  # Wait for all brokers to acknowledge
}

producer = Producer(conf)

# Generate random test data
def generate_test_data():
    client_id = f"client_{random.randint(1000, 9999)}"
    transaction_id = str(uuid.uuid4())
    transaction_type = random.choice(["TRANSFER","DEBIT","CASH_OUT","CASH_IN"])
    amount = random.uniform(1.0, 10.0)
    old_balance = random.uniform(0.0, 5000.0)
    new_balance = old_balance - amount if transaction_type == "purchase" else old_balance + amount

    return {
        "client_id": client_id,
        "transaction_id": transaction_id,
        "type": transaction_type,
        "amount": amount,
        "oldbalanceOrg": old_balance,
        "newbalanceOrig": new_balance
    }

# Function to serialize data into Avro format
def serialize_avro(data, schema):
    with io.BytesIO() as buf:
        writer = fastavro.writer(buf, schema, [data])
        return buf.getvalue()

# Produce data to Kafka
def produce_to_kafka():
    for _ in range(30):  # Adjust the number of records to send
        test_data = generate_test_data()
        avro_data = serialize_avro(test_data, avro_schema)
        
        # Produce message to Kafka
        producer.produce(topic=TOPIC, key=test_data["transaction_id"], value=avro_data)
        print(f"Sent data: {test_data}")
        producer.flush()

    

# Start the producer
if __name__ == "__main__":
    produce_to_kafka()
# Out:
# Sent data: {'client_id': 'client_9447', 'transaction_id': '4bc409e0-cac6-459a-b908-e4609ebd421c', 'type': 'DEBIT', 'amount': 8.577732595887085, 'oldbalanceOrg': 2410.708499314125, 'newbalanceOrig': 2419.2862319100122}
# Sent data: {'client_id': 'client_6494', 'transaction_id': '4fa29726-f8f5-499c-8910-4dd3f0f323bf', 'type': 'CASH_OUT', 'amount': 3.0313582725147676, 'oldbalanceOrg': 88.10038121557562, 'newbalanceOrig': 91.13173948809039}
# Sent data: {'client_id': 'client_1647', 'transaction_id': '785a2a74-28ef-4c28-b799-52bb358f8919', 'type': 'TRANSFER', 'amount': 7.185952256766741, 'oldbalanceOrg': 2166.0909610882086, 'newbalanceOrig': 2173.276913344975}
# Sent data: {'client_id': 'client_6683', 'transaction_id': '223f68cf-6d3b-4a13-b980-a6e9b9ba0896', 'type': 'TRANSFER', 'amount': 9.62940198071514, 'oldbalanceOrg': 225.0988883685423, 'newbalanceOrig': 234.72829034925743}
# Sent data: {'client_id': 'client_6091', 'transaction_id': 'cb91d3f4-2734-4c1d-83ff-408f81a20f8f', 'type': 'DEBIT', 'amount': 8.99104026177813, 'oldbalanceOrg': 1427.290601359037, 'newbalanceOrig': 1436.2816416208152}
# Sent data: {'client_id': 'client_8460', 'transaction_id': '74c26dd8-6e45-475f-9825-0c5fbade91c4', 'type': 'CASH_IN', 'amount': 8.999332126201852, 'oldbalanceOrg': 3824.3631371851643, 'newbalanceOrig': 3833.362469311366}
# Sent data: {'client_id': 'client_4477', 'transaction_id': 'f11989f1-4dc9-456f-9c4c-0556f1502045', 'type': 'CASH_OUT', 'amount': 8.197997775938061, 'oldbalanceOrg': 4176.500275356284, 'newbalanceOrig': 4184.698273132222}
# Sent data: {'client_id': 'client_9231', 'transaction_id': '9a622c81-3368-4193-838f-3c6fcb7212e8', 'type': 'CASH_OUT', 'amount': 8.652918182510346, 'oldbalanceOrg': 1248.3274210756795, 'newbalanceOrig': 1256.9803392581898}
# Sent data: {'client_id': 'client_9748', 'transaction_id': 'ca652173-af24-41e1-950b-c797403647bf', 'type': 'DEBIT', 'amount': 7.149736125501011, 'oldbalanceOrg': 2530.6951120345657, 'newbalanceOrig': 2537.8448481600667}
# Sent data: {'client_id': 'client_2312', 'transaction_id': '12b2af3a-8196-4ee2-b223-5c79bb701381', 'type': 'TRANSFER', 'amount': 1.1716586265764706, 'oldbalanceOrg': 711.155610490714, 'newbalanceOrig': 712.3272691172905}
# Sent data: {'client_id': 'client_3357', 'transaction_id': 'c39a0717-8872-4747-a1c4-164658ec68d8', 'type': 'CASH_OUT', 'amount': 6.958606605001003, 'oldbalanceOrg': 3130.3301207347604, 'newbalanceOrig': 3137.2887273397614}
# Sent data: {'client_id': 'client_4364', 'transaction_id': '28fcc499-10ec-4c42-b584-f998462be4df', 'type': 'DEBIT', 'amount': 2.4747445934093877, 'oldbalanceOrg': 1608.2983945529927, 'newbalanceOrig': 1610.7731391464022}
# Sent data: {'client_id': 'client_6819', 'transaction_id': '03ad5c07-e1d2-4ce4-9951-0fda61a194dd', 'type': 'CASH_IN', 'amount': 6.722141547119383, 'oldbalanceOrg': 921.7433125764712, 'newbalanceOrig': 928.4654541235906}
# Sent data: {'client_id': 'client_1946', 'transaction_id': '3145f875-32c8-46f8-bbad-fb9099a08b6a', 'type': 'TRANSFER', 'amount': 1.478675339254285, 'oldbalanceOrg': 4095.471563888732, 'newbalanceOrig': 4096.9502392279865}
# Sent data: {'client_id': 'client_8339', 'transaction_id': 'cef3aa32-e5ad-444e-86d7-f5c844f2d535', 'type': 'CASH_IN', 'amount': 1.7024867381525957, 'oldbalanceOrg': 4122.511159616869, 'newbalanceOrig': 4124.213646355021}
# Sent data: {'client_id': 'client_5790', 'transaction_id': '0676f269-063d-483e-b1f4-2c5174f6ae4a', 'type': 'DEBIT', 'amount': 8.868021599399988, 'oldbalanceOrg': 4930.217964460526, 'newbalanceOrig': 4939.085986059926}
# Sent data: {'client_id': 'client_5435', 'transaction_id': '9f9a8bd8-6770-4142-a6e0-579ca83085bc', 'type': 'CASH_OUT', 'amount': 6.36695331252807, 'oldbalanceOrg': 806.97684476913, 'newbalanceOrig': 813.3437980816581}
# Sent data: {'client_id': 'client_6926', 'transaction_id': '02b8cf81-4d44-4050-a466-7c394f69a2f8', 'type': 'DEBIT', 'amount': 9.580720708300762, 'oldbalanceOrg': 3494.086588581359, 'newbalanceOrig': 3503.66730928966}
# Sent data: {'client_id': 'client_8062', 'transaction_id': '045d8bb0-0cc8-433b-91c8-caa21afafb8e', 'type': 'CASH_OUT', 'amount': 2.909241140405009, 'oldbalanceOrg': 2026.7090984779013, 'newbalanceOrig': 2029.6183396183062}
# Sent data: {'client_id': 'client_9199', 'transaction_id': '47e74117-233d-4a0c-bb29-7c3c1e2330b1', 'type': 'DEBIT', 'amount': 1.1033908886414934, 'oldbalanceOrg': 1624.672434985638, 'newbalanceOrig': 1625.7758258742795}
# Sent data: {'client_id': 'client_1779', 'transaction_id': 'ff4d1e64-22fc-4b68-998b-f17dca0ea468', 'type': 'DEBIT', 'amount': 8.715272420434882, 'oldbalanceOrg': 1474.608699139332, 'newbalanceOrig': 1483.323971559767}
# Sent data: {'client_id': 'client_1983', 'transaction_id': '48e4867a-cb6f-487e-be69-203fd7ceb6f7', 'type': 'TRANSFER', 'amount': 6.294747926433867, 'oldbalanceOrg': 2307.7917184875328, 'newbalanceOrig': 2314.0864664139667}
# Sent data: {'client_id': 'client_3754', 'transaction_id': 'fa33f5c0-9f30-462c-9980-e3357cb8f235', 'type': 'TRANSFER', 'amount': 2.442270677547705, 'oldbalanceOrg': 2518.4067354389144, 'newbalanceOrig': 2520.849006116462}
# Sent data: {'client_id': 'client_7853', 'transaction_id': '09ce8b6b-acde-44b9-bcf2-8f0dd2d36024', 'type': 'CASH_OUT', 'amount': 6.827110093175719, 'oldbalanceOrg': 4505.71103528009, 'newbalanceOrig': 4512.538145373266}
# Sent data: {'client_id': 'client_2714', 'transaction_id': '8429d299-e517-4196-af1f-b2fbb083f944', 'type': 'DEBIT', 'amount': 8.449616337230417, 'oldbalanceOrg': 1419.5633067066237, 'newbalanceOrig': 1428.0129230438542}
# Sent data: {'client_id': 'client_7547', 'transaction_id': '534eabf0-19e9-42b6-947a-5d8c491606bc', 'type': 'TRANSFER', 'amount': 4.202443381310181, 'oldbalanceOrg': 4431.13140359445, 'newbalanceOrig': 4435.33384697576}
# Sent data: {'client_id': 'client_9011', 'transaction_id': 'e22d1d2f-874b-48db-941f-8d3f1ed20f41', 'type': 'CASH_OUT', 'amount': 5.640526122877635, 'oldbalanceOrg': 4168.892206527364, 'newbalanceOrig': 4174.532732650241}
# Sent data: {'client_id': 'client_8335', 'transaction_id': '48dad966-9362-420a-81da-363a7e62a6a2', 'type': 'CASH_IN', 'amount': 6.6406549041997565, 'oldbalanceOrg': 1278.090504124203, 'newbalanceOrig': 1284.7311590284028}
# Sent data: {'client_id': 'client_6560', 'transaction_id': 'bbc19170-31b6-418c-bce5-ff4737bfc45d', 'type': 'CASH_IN', 'amount': 3.5778743114802376, 'oldbalanceOrg': 2789.1859919949784, 'newbalanceOrig': 2792.7638663064586}
# Sent data: {'client_id': 'client_3956', 'transaction_id': '0c10e322-3623-4f52-9ac9-f4a4b2aceefa', 'type': 'CASH_IN', 'amount': 5.20915172563198, 'oldbalanceOrg': 196.06410744070712, 'newbalanceOrig': 201.2732591663391}
