# %%
import json
import random
import uuid
import time
from confluent_kafka import Producer
import fastavro
import io

# Schéma Avro
insurance_avro_schema = {
    "type": "record",
    "name": "InsuranceTransaction",
    "namespace": "com.insurance.data",
    "fields": [
        {"name": "client_id", "type": "string"},
        {"name": "transaction_id", "type": "string"},
        {"name": "high_education_ind", "type": ["int", "null"], "default": None},
        {"name": "past_num_of_claims", "type": ["int", "null"], "default": None},
        {"name": "gender", "type": ["string", "null"], "default": None},
        {"name": "address_change_ind", "type": ["int", "null"], "default": None},
        {"name": "witness_present_ind", "type": ["int", "null"], "default": None},
        {"name": "marital_status", "type": ["int", "null"], "default": None},
        {"name": "channel", "type": ["string", "null"], "default": None},
        {"name": "accident_site", "type": ["string", "null"], "default": None},
        {"name": "living_status", "type": ["string", "null"], "default": None},
        {"name": "vehicle_category", "type": ["string", "null"], "default": None}
    ]
}

# Configuration Kafka
KAFKA_BROKER = "host.docker.internal:9092"  # Remplace avec l'URL de ton broker Kafka
TOPIC = "raw_insurance_data"  # Nom du topic Kafka

conf = {
    'bootstrap.servers': KAFKA_BROKER,
    'acks': 'all',  # Attendre l'accusé de réception de tous les brokers
}

producer = Producer(conf)

# Génération de données fictives
def generate_test_data():
    return {
        "client_id": f"client_{random.randint(1000, 9999)}",
        "transaction_id": str(uuid.uuid4()),
        "high_education_ind": random.choice([0, 1, None]),
        "past_num_of_claims": random.choice([0, 1, 2, 3, None]),
        "gender": random.choice(["M", "F", None]),
        "address_change_ind": random.choice([0, 1, None]),
        "witness_present_ind": random.choice([0, 1, None]),
        "marital_status":random.choice([0, 1, None]),  
        "channel":random.choice(["Phone", None]),
        "accident_site": random.choice(["Parking Lot", "Rural", None]),
        "living_status": random.choice(["Owned", "Rent", None]),
        "vehicle_category": random.choice(["Medium", "SUV", "Truck", None])
    }

# Sérialisation des données en Avro
def serialize_avro(data, schema):
    with io.BytesIO() as buf:
        fastavro.writer(buf, schema, [data])
        return buf.getvalue()

# Envoi des données à Kafka
def produce_to_kafka():
    for _ in range(20):  # Nombre de messages à envoyer
        test_data = generate_test_data()
        avro_data = serialize_avro(test_data, insurance_avro_schema)
        
        producer.produce(topic=TOPIC, key=test_data["transaction_id"], value=avro_data)
        print(f"Sent data: {test_data}")
        producer.flush()
        time.sleep(1)  # Ajuster la fréquence d'envoi

# Lancer le producteur
if __name__ == "__main__":
    produce_to_kafka()
# Out:
# Sent data: {'client_id': 'client_1392', 'transaction_id': 'd384a4b4-db0f-4b2e-bcdb-176555d8376d', 'high_education_ind': 0, 'past_num_of_claims': None, 'gender': None, 'address_change_ind': 0, 'witness_present_ind': 1, 'marital_status': 1, 'channel': 'Phone', 'accident_site': 'Rural', 'living_status': 'Owned', 'vehicle_category': 'SUV'}
# Sent data: {'client_id': 'client_5402', 'transaction_id': '6a478676-543a-4c07-bbb7-e8126bc02580', 'high_education_ind': None, 'past_num_of_claims': 1, 'gender': 'M', 'address_change_ind': 1, 'witness_present_ind': None, 'marital_status': 0, 'channel': None, 'accident_site': None, 'living_status': 'Owned', 'vehicle_category': 'Truck'}
# Sent data: {'client_id': 'client_6493', 'transaction_id': 'f07f9b99-6fc3-4e0c-bf63-0b574363e9d4', 'high_education_ind': 1, 'past_num_of_claims': 1, 'gender': 'F', 'address_change_ind': None, 'witness_present_ind': 1, 'marital_status': 0, 'channel': None, 'accident_site': 'Parking Lot', 'living_status': 'Owned', 'vehicle_category': 'SUV'}
# Sent data: {'client_id': 'client_6259', 'transaction_id': '15556b49-c0c2-458e-94d7-cd9665378b0c', 'high_education_ind': 1, 'past_num_of_claims': None, 'gender': 'F', 'address_change_ind': 1, 'witness_present_ind': 1, 'marital_status': None, 'channel': None, 'accident_site': 'Parking Lot', 'living_status': None, 'vehicle_category': None}
# Sent data: {'client_id': 'client_7943', 'transaction_id': 'edbdac9f-e2c7-459e-ad0d-8a435ba6aa4d', 'high_education_ind': 0, 'past_num_of_claims': 3, 'gender': 'F', 'address_change_ind': 0, 'witness_present_ind': None, 'marital_status': 1, 'channel': None, 'accident_site': None, 'living_status': None, 'vehicle_category': 'Truck'}
# Sent data: {'client_id': 'client_9229', 'transaction_id': '397654a3-9a35-4012-abaa-faacf6005d40', 'high_education_ind': 0, 'past_num_of_claims': None, 'gender': 'M', 'address_change_ind': 0, 'witness_present_ind': None, 'marital_status': None, 'channel': 'Phone', 'accident_site': None, 'living_status': 'Owned', 'vehicle_category': None}
# Sent data: {'client_id': 'client_7658', 'transaction_id': '58f56d2a-a98f-425e-9971-4303a2e42714', 'high_education_ind': 0, 'past_num_of_claims': 2, 'gender': 'M', 'address_change_ind': 0, 'witness_present_ind': None, 'marital_status': 0, 'channel': 'Phone', 'accident_site': 'Parking Lot', 'living_status': 'Rent', 'vehicle_category': 'Medium'}
# Sent data: {'client_id': 'client_2588', 'transaction_id': '410ea529-4f99-4c1e-8501-dc7abef7e33d', 'high_education_ind': 1, 'past_num_of_claims': 1, 'gender': None, 'address_change_ind': 1, 'witness_present_ind': 1, 'marital_status': 1, 'channel': None, 'accident_site': 'Parking Lot', 'living_status': 'Owned', 'vehicle_category': 'Truck'}
# Sent data: {'client_id': 'client_8843', 'transaction_id': 'dd23b558-ba76-4ff6-969f-39296b78a4aa', 'high_education_ind': 1, 'past_num_of_claims': 0, 'gender': 'M', 'address_change_ind': 0, 'witness_present_ind': None, 'marital_status': 1, 'channel': 'Phone', 'accident_site': 'Parking Lot', 'living_status': 'Rent', 'vehicle_category': 'Medium'}
# Sent data: {'client_id': 'client_7971', 'transaction_id': '0c0b1e56-40ef-4c9a-a58b-4dc8a806c6a6', 'high_education_ind': 1, 'past_num_of_claims': None, 'gender': 'F', 'address_change_ind': 1, 'witness_present_ind': 0, 'marital_status': 1, 'channel': 'Phone', 'accident_site': 'Rural', 'living_status': 'Rent', 'vehicle_category': 'SUV'}
# Sent data: {'client_id': 'client_8116', 'transaction_id': 'd72087c2-6a69-45f4-8173-b01471d07c4b', 'high_education_ind': 1, 'past_num_of_claims': 2, 'gender': None, 'address_change_ind': 0, 'witness_present_ind': 0, 'marital_status': None, 'channel': None, 'accident_site': 'Rural', 'living_status': None, 'vehicle_category': 'SUV'}
# Sent data: {'client_id': 'client_7654', 'transaction_id': '38d7adbb-e195-4783-8795-f0eda3c3bbe5', 'high_education_ind': 0, 'past_num_of_claims': 3, 'gender': 'M', 'address_change_ind': None, 'witness_present_ind': 1, 'marital_status': 0, 'channel': 'Phone', 'accident_site': 'Rural', 'living_status': 'Rent', 'vehicle_category': None}
# Sent data: {'client_id': 'client_1806', 'transaction_id': 'ed5104bc-177f-4e18-a3a6-537a81be1ed5', 'high_education_ind': None, 'past_num_of_claims': 1, 'gender': None, 'address_change_ind': None, 'witness_present_ind': 0, 'marital_status': 1, 'channel': None, 'accident_site': None, 'living_status': 'Rent', 'vehicle_category': 'Truck'}
# Sent data: {'client_id': 'client_5933', 'transaction_id': '539b591d-42d5-438a-836c-0d4466498df1', 'high_education_ind': None, 'past_num_of_claims': 3, 'gender': 'F', 'address_change_ind': 0, 'witness_present_ind': None, 'marital_status': 1, 'channel': None, 'accident_site': 'Parking Lot', 'living_status': 'Rent', 'vehicle_category': 'Medium'}
# Sent data: {'client_id': 'client_3813', 'transaction_id': '62475fb9-811b-480a-afa6-28ea6e6a674e', 'high_education_ind': 0, 'past_num_of_claims': 0, 'gender': 'F', 'address_change_ind': 0, 'witness_present_ind': None, 'marital_status': 0, 'channel': None, 'accident_site': 'Parking Lot', 'living_status': None, 'vehicle_category': 'Truck'}
# Sent data: {'client_id': 'client_2531', 'transaction_id': '68e5800b-4702-465c-b3d6-eed8222b5da9', 'high_education_ind': None, 'past_num_of_claims': 0, 'gender': 'F', 'address_change_ind': 0, 'witness_present_ind': 0, 'marital_status': None, 'channel': None, 'accident_site': None, 'living_status': 'Rent', 'vehicle_category': 'Truck'}
# Sent data: {'client_id': 'client_4108', 'transaction_id': '7ab84064-ab4d-43ce-acae-479a2ae19275', 'high_education_ind': 0, 'past_num_of_claims': 2, 'gender': 'M', 'address_change_ind': 1, 'witness_present_ind': 1, 'marital_status': 1, 'channel': None, 'accident_site': None, 'living_status': None, 'vehicle_category': 'Truck'}
# Sent data: {'client_id': 'client_9704', 'transaction_id': 'c68043aa-d6a8-4c0b-a43c-9c17ab1828b3', 'high_education_ind': 1, 'past_num_of_claims': 3, 'gender': 'F', 'address_change_ind': None, 'witness_present_ind': 1, 'marital_status': None, 'channel': None, 'accident_site': 'Parking Lot', 'living_status': 'Rent', 'vehicle_category': 'SUV'}
# Sent data: {'client_id': 'client_5228', 'transaction_id': '42147eb7-1ca6-4e8a-8a9b-82528561a912', 'high_education_ind': 0, 'past_num_of_claims': None, 'gender': 'F', 'address_change_ind': 1, 'witness_present_ind': 1, 'marital_status': 1, 'channel': 'Phone', 'accident_site': 'Rural', 'living_status': None, 'vehicle_category': None}
# Sent data: {'client_id': 'client_3574', 'transaction_id': '0752b48f-e028-4316-bdba-47940a6dc668', 'high_education_ind': 0, 'past_num_of_claims': 3, 'gender': 'F', 'address_change_ind': 1, 'witness_present_ind': 1, 'marital_status': 1, 'channel': None, 'accident_site': 'Rural', 'living_status': 'Rent', 'vehicle_category': None}
